# %% [markdown]
# # 4.8 Grouping data and aggregating variables - Part 1

# %% [markdown]
# ## This script contains the following points:
#
# ### Step 1 - Import data
# ### Step 2 - Group data
# ### Step 3 - Analyze results
# ### Step 4 - Create a customer loyalty flag
# ### Step 5 - Create basic statistics
# ### Step 6 - Create a spending flag
# ### Step 7 - Create an order frequency flag
# ### Step 9 - Export data

# %%
# Step 1 - Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Assign project folder path to a variable

path = r'C:\Users\jomok\Documents\Career Foundry\Achievement 4\07-2023 Instacart Basket Analysis'

# %% [markdown]
# ## Step 1. Import data

# %%
# Import data

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Check output

ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2398795        1    prior             2                  3
# 2    473747        1    prior             3                  3
# 3   2254736        1    prior             4                  4
# 4    431534        1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     0.0         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ... prices    price_range_loc     busiest_day  \
# 0          0  ...    9.0  Mid-range product  Regularly busy
# 1          1  ...    9.0  Mid-range product    Slowest days
# 2          1  ...    9.0  Mid-range product    Slowest days
# 3          1  ...    9.0  Mid-range product    Slowest days
# 4          1  ...    9.0  Mid-range product    Slowest days
#
#    busiest_period_of_day max_order  loyalty_flag avg_price  spending_flag  \
# 0         Average orders        10  New customer  6.367797    Low spender
# 1         Average orders        10  New customer  6.367797    Low spender
# 2            Most orders        10  New customer  6.367797    Low spender
# 3         Average orders        10  New customer  6.367797    Low spender
# 4            Most orders        10  New customer  6.367797    Low spender
#
#   median_days_since_prior_order  order_frequency_flag
# 0                          20.0      Regular customer
# 1                          20.0      Regular customer
# 2                          20.0      Regular customer
# 3                          20.0      Regular customer
# 4                          20.0      Regular customer
#
# [5 rows x 23 columns]

# %%
# Check shape

ords_prods_merge.shape
# Out:
# (32404859, 23)

# %% [markdown]
# ## Step 2 - Group data

# %%
# Split data into "department_id" groups and aggregate mean values by "order_number" column

ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ## Step 3 - Results for the entire dataframe contains output for every department, whereas the first million rows was not representative of all departments.  The mean value range also increased to now 15.22 to 22.90 for the entire dataframe, as opposed to a smaller range of 17.47 to 19.46 for the 1 million first rows subset dataframe.

# %% [markdown]
# ## Step 4 - Create a customer loyalty flag

# %%
# Create "max_order" column

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check output

ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     0.0         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
#
#     reordered  ... prices    price_range_loc     busiest_day  \
# 0           0  ...    9.0  Mid-range product  Regularly busy
# 1           1  ...    9.0  Mid-range product    Slowest days
# 2           1  ...    9.0  Mid-range product    Slowest days
# 3           1  ...    9.0  Mid-range product    Slowest days
# 4           1  ...    9.0  Mid-range product    Slowest days
# 5           1  ...    9.0  Mid-range product  Regularly busy
# 6           1  ...    9.0  Mid-range product    Busiest days
# 7           1  ...    9.0  Mid-range product    Busiest days
# 8           1  ...    9.0  Mid-range product    Busiest days
# 9           1  ...    9.0  Mid-range product    Slowest days
# 10          0  ...    9.0  Mid-range product    Busiest days
# 11          1  ...    9.0  Mid-range product  Regularly busy
# 12          1  ...    9.0  Mid-range product  Regularly busy
# 13          1  ...    9.0  Mid-range product    Busiest days
# 14          1  ...    9.0  Mid-range product    Busiest days
#
#     busiest_period_of_day max_order      loyalty_flag avg_price  \
# 0          Average orders        10      New customer  6.367797
# 1          Average orders        10      New customer  6.367797
# 2             Most orders        10      New customer  6.367797
# 3          Average orders        10      New customer  6.367797
# 4             Most orders        10      New customer  6.367797
# 5          Average orders        10      New customer  6.367797
# 6             Most orders        10      New customer  6.367797
# 7             Most orders        10      New customer  6.367797
# 8             Most orders        10      New customer  6.367797
# 9          Average orders        10      New customer  6.367797
# 10            Most orders        22  Regular customer  3.980556
# 11            Most orders        22  Regular customer  3.980556
# 12            Most orders        22  Regular customer  3.980556
# 13            Most orders        22  Regular customer  3.980556
# 14            Most orders        22  Regular customer  3.980556
#
#     spending_flag median_days_since_prior_order  order_frequency_flag
# 0     Low spender                          20.0      Regular customer
# 1     Low spender                          20.0      Regular customer
# 2     Low spender                          20.0      Regular customer
# 3     Low spender                          20.0      Regular customer
# 4     Low spender                          20.0      Regular customer
# 5     Low spender                          20.0      Regular customer
# 6     Low spender                          20.0      Regular customer
# 7     Low spender                          20.0      Regular customer
# 8     Low spender                          20.0      Regular customer
# 9     Low spender                          20.0      Regular customer
# 10    Low spender                           8.0     Frequent customer
# 11    Low spender                           8.0     Frequent customer
# 12    Low spender                           8.0     Frequent customer
# 13    Low spender                           8.0     Frequent customer
# 14    Low spender                           8.0     Frequent customer
#
# [15 rows x 23 columns]

# %%
# Tell pandas not to assign any options for maximum number of rows to display

pd.options.display.max_rows = None

# %%
# Check output for 100 rows

ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
# 15   2293453       19    prior             2                  5
# 16   1973799       19    prior             5                  6
# 17    532817       19    prior             7                  4
# 18   1573906       21    prior            10                  3
# 19   1593000       31    prior            10                  3
# 20   2231262       31    prior            17                  3
# 21   2580647       43    prior             6                  4
# 22   2187180       43    prior             9                  4
# 23   2497897       52    prior             1                  1
# 24   1318871       52    prior             2                  1
# 25   1261384       52    prior             3                  1
# 26    580568       52    prior             5                  2
# 27   2428073       52    prior             7                  2
# 28    342306       52    prior             9                  1
# 29   1520353       52    prior            10                  2
# 30   2542086       52    prior            11                  2
# 31    944694       52    prior            12                  1
# 32   1268191       52    prior            15                  2
# 33   1122089       52    prior            17                  2
# 34   1498922       52    prior            18                  2
# 35    180919       52    prior            19                  3
# 36   2695875       52    prior            21                  5
# 37   3205960       67    prior             1                  3
# 38    970922       67    prior             2                  1
# 39    596585       67    prior             3                  1
# 40   2037087       67    prior             4                  2
# 41   2474111       67    prior             5                  3
# 42   1568481       67    prior             6                  3
# 43   2048527       67    prior             8                  2
# 44   2389031       67    prior             9                  2
# 45   2378562       67    prior            10                  1
# 46   1515698       67    prior            11                  1
# 47   1928050       67    prior            12                  2
# 48   1949274       67    prior            13                  1
# 49    551869       67    prior            14                  1
# 50    768572       67    prior            16                  4
# 51    150528       67    prior            18                  5
# 52     29758       67    prior            19                  0
# 53   1558976       67    prior            21                  1
# 54    863974       67    prior            22                  1
# 55   2308399       67    prior            23                  1
# 56   2759128       81    prior             3                  1
# 57   1812985       81    prior             5                  2
# 58   1889835       82    prior             1                  3
# 59    499460       82    prior             3                  5
# 60   2728456       82    prior             4                  0
# 61   2653743       82    prior             6                  4
# 62   1358880       82    prior             9                  1
# 63    343588       82    prior            10                  2
# 64   3034663       82    prior            15                  2
# 65    147262       82    prior            18                  1
# 66   3144004       82    prior            19                  2
# 67   2126069       98    prior             3                  0
# 68   2210120       98    prior             7                  5
# 69    681011       98    prior             9                  3
# 70   2846344       98    prior            11                  4
# 71    747431       98    prior            12                  6
# 72   2383054       98    prior            13                  4
# 73   1993729       98    prior            14                  5
# 74   1403849      109    prior             3                  3
# 75    520620      120    prior             1                  3
# 76   3273029      120    prior             3                  2
# 77   1861943      185    prior             2                  1
# 78   2040988      195    prior             1                  1
# 79   1680569      195    prior             8                  1
# 80    276171      195    prior            19                  5
# 81   2744976      195    prior            22                  5
# 82   2781919      195    prior            25                  1
# 83   1738718      195    prior            31                  2
# 84   3058369      195    prior            34                  3
# 85   1485596      195    prior            37                  2
# 86    417035      195    prior            40                  3
# 87   1615297      195    prior            47                  5
# 88   1765587      195    prior            52                  3
# 89    745908      195    prior            57                  4
# 90   2505656      222    prior            17                  2
# 91   3268370      222    prior            38                  5
# 92   2016711      290    prior             9                  5
# 93   2706088      290    prior            28                  6
# 94   1952286      331    prior             6                  5
# 95   3226575      360    prior             1                  5
# 96   1469869      377    prior             3                  5
# 97   1927023      387    prior             2                  4
# 98    858092      420    prior             4                  1
# 99    119314      420    prior             5                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     0.0         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
# 20                 11                     8.0         196                 14
# 21                 16                     4.0         196                  9
# 22                 12                     3.0         196                  1
# 23                  9                     0.0         196                  4
# 24                 10                     7.0         196                  5
# 25                 10                     7.0         196                  3
# 26                 10                     8.0         196                  6
# 27                  7                     8.0         196                  5
# 28                 11                     7.0         196                  5
# 29                 10                     8.0         196                  4
# 30                  9                     7.0         196                  3
# 31                 16                     6.0         196                  7
# 32                 11                     8.0         196                  3
# 33                 10                     6.0         196                  4
# 34                 10                    14.0         196                  6
# 35                  8                     8.0         196                  4
# 36                 10                    30.0         196                  1
# 37                 11                     0.0         196                  1
# 38                 15                     5.0         196                  2
# 39                 13                     7.0         196                  2
# 40                  9                     8.0         196                  1
# 41                 14                     8.0         196                  2
# 42                 12                     7.0         196                  2
# 43                 11                     7.0         196                  1
# 44                 14                     7.0         196                  1
# 45                 10                     6.0         196                  1
# 46                 11                     7.0         196                  1
# 47                 12                     8.0         196                  1
# 48                 10                     6.0         196                  1
# 49                  9                     7.0         196                  1
# 50                 10                     9.0         196                  1
# 51                 16                     4.0         196                  1
# 52                 14                     9.0         196                  2
# 53                  9                     5.0         196                  2
# 54                 11                    14.0         196                  3
# 55                 14                    14.0         196                  1
# 56                  9                    14.0         196                  2
# 57                 20                    30.0         196                  1
# 58                 15                     0.0         196                  6
# 59                 10                     5.0         196                  2
# 60                 11                    16.0         196                  1
# 61                  9                    13.0         196                  5
# 62                 10                    30.0         196                  1
# 63                 11                     1.0         196                  1
# 64                 11                    12.0         196                  1
# 65                 13                     7.0         196                  1
# 66                 15                     8.0         196                  1
# 67                  9                    25.0         196                  7
# 68                 14                     5.0         196                  1
# 69                  9                    30.0         196                  1
# 70                 13                    15.0         196                  2
# 71                 13                    30.0         196                  4
# 72                 11                    30.0         196                  1
# 73                  8                     8.0         196                  2
# 74                 17                     9.0         196                  5
# 75                 11                     0.0         196                  2
# 76                  8                    19.0         196                  2
# 77                 12                    25.0         196                 10
# 78                 14                     0.0         196                  2
# 79                  9                     4.0         196                  2
# 80                 11                     3.0         196                  2
# 81                 10                     7.0         196                  2
# 82                 14                     4.0         196                  1
# 83                  8                     4.0         196                  2
# 84                 10                     6.0         196                  2
# 85                 15                     0.0         196                  2
# 86                 16                     2.0         196                  2
# 87                 10                     2.0         196                  2
# 88                 12                     2.0         196                  3
# 89                 11                     3.0         196                  3
# 90                 12                     1.0         196                  2
# 91                 15                     1.0         196                  6
# 92                 19                     6.0         196                  8
# 93                 10                     7.0         196                 16
# 94                 16                    30.0         196                  8
# 95                 12                     0.0         196                  1
# 96                 17                     3.0         196                  9
# 97                 10                    22.0         196                  3
# 98                 19                    30.0         196                  2
# 99                 19                    16.0         196                  2
#
#     reordered  ... prices    price_range_loc     busiest_day  \
# 0           0  ...    9.0  Mid-range product  Regularly busy
# 1           1  ...    9.0  Mid-range product    Slowest days
# 2           1  ...    9.0  Mid-range product    Slowest days
# 3           1  ...    9.0  Mid-range product    Slowest days
# 4           1  ...    9.0  Mid-range product    Slowest days
# 5           1  ...    9.0  Mid-range product  Regularly busy
# 6           1  ...    9.0  Mid-range product    Busiest days
# 7           1  ...    9.0  Mid-range product    Busiest days
# 8           1  ...    9.0  Mid-range product    Busiest days
# 9           1  ...    9.0  Mid-range product    Slowest days
# 10          0  ...    9.0  Mid-range product    Busiest days
# 11          1  ...    9.0  Mid-range product  Regularly busy
# 12          1  ...    9.0  Mid-range product  Regularly busy
# 13          1  ...    9.0  Mid-range product    Busiest days
# 14          1  ...    9.0  Mid-range product    Busiest days
# 15          0  ...    9.0  Mid-range product  Regularly busy
# 16          1  ...    9.0  Mid-range product  Regularly busy
# 17          1  ...    9.0  Mid-range product    Slowest days
# 18          0  ...    9.0  Mid-range product    Slowest days
# 19          0  ...    9.0  Mid-range product    Slowest days
# 20          1  ...    9.0  Mid-range product    Slowest days
# 21          0  ...    9.0  Mid-range product    Slowest days
# 22          1  ...    9.0  Mid-range product    Slowest days
# 23          0  ...    9.0  Mid-range product    Busiest days
# 24          1  ...    9.0  Mid-range product    Busiest days
# 25          1  ...    9.0  Mid-range product    Busiest days
# 26          1  ...    9.0  Mid-range product  Regularly busy
# 27          1  ...    9.0  Mid-range product  Regularly busy
# 28          1  ...    9.0  Mid-range product    Busiest days
# 29          1  ...    9.0  Mid-range product  Regularly busy
# 30          1  ...    9.0  Mid-range product  Regularly busy
# 31          1  ...    9.0  Mid-range product    Busiest days
# 32          1  ...    9.0  Mid-range product  Regularly busy
# 33          1  ...    9.0  Mid-range product  Regularly busy
# 34          1  ...    9.0  Mid-range product  Regularly busy
# 35          1  ...    9.0  Mid-range product    Slowest days
# 36          1  ...    9.0  Mid-range product  Regularly busy
# 37          0  ...    9.0  Mid-range product    Slowest days
# 38          1  ...    9.0  Mid-range product    Busiest days
# 39          1  ...    9.0  Mid-range product    Busiest days
# 40          1  ...    9.0  Mid-range product  Regularly busy
# 41          1  ...    9.0  Mid-range product    Slowest days
# 42          1  ...    9.0  Mid-range product    Slowest days
# 43          1  ...    9.0  Mid-range product  Regularly busy
# 44          1  ...    9.0  Mid-range product  Regularly busy
# 45          1  ...    9.0  Mid-range product    Busiest days
# 46          1  ...    9.0  Mid-range product    Busiest days
# 47          1  ...    9.0  Mid-range product  Regularly busy
# 48          1  ...    9.0  Mid-range product    Busiest days
# 49          1  ...    9.0  Mid-range product    Busiest days
# 50          1  ...    9.0  Mid-range product    Slowest days
# 51          1  ...    9.0  Mid-range product  Regularly busy
# 52          1  ...    9.0  Mid-range product    Busiest days
# 53          1  ...    9.0  Mid-range product    Busiest days
# 54          1  ...    9.0  Mid-range product    Busiest days
# 55          1  ...    9.0  Mid-range product    Busiest days
# 56          0  ...    9.0  Mid-range product    Busiest days
# 57          1  ...    9.0  Mid-range product  Regularly busy
# 58          0  ...    9.0  Mid-range product    Slowest days
# 59          1  ...    9.0  Mid-range product  Regularly busy
# 60          1  ...    9.0  Mid-range product    Busiest days
# 61          1  ...    9.0  Mid-range product    Slowest days
# 62          1  ...    9.0  Mid-range product    Busiest days
# 63          1  ...    9.0  Mid-range product  Regularly busy
# 64          1  ...    9.0  Mid-range product  Regularly busy
# 65          1  ...    9.0  Mid-range product    Busiest days
# 66          1  ...    9.0  Mid-range product  Regularly busy
# 67          0  ...    9.0  Mid-range product    Busiest days
# 68          1  ...    9.0  Mid-range product  Regularly busy
# 69          1  ...    9.0  Mid-range product    Slowest days
# 70          1  ...    9.0  Mid-range product    Slowest days
# 71          1  ...    9.0  Mid-range product  Regularly busy
# 72          1  ...    9.0  Mid-range product    Slowest days
# 73          1  ...    9.0  Mid-range product  Regularly busy
# 74          0  ...    9.0  Mid-range product    Slowest days
# 75          0  ...    9.0  Mid-range product    Slowest days
# 76          1  ...    9.0  Mid-range product  Regularly busy
# 77          0  ...    9.0  Mid-range product    Busiest days
# 78          0  ...    9.0  Mid-range product    Busiest days
# 79          1  ...    9.0  Mid-range product    Busiest days
# 80          1  ...    9.0  Mid-range product  Regularly busy
# 81          1  ...    9.0  Mid-range product  Regularly busy
# 82          1  ...    9.0  Mid-range product    Busiest days
# 83          1  ...    9.0  Mid-range product  Regularly busy
# 84          1  ...    9.0  Mid-range product    Slowest days
# 85          1  ...    9.0  Mid-range product  Regularly busy
# 86          1  ...    9.0  Mid-range product    Slowest days
# 87          1  ...    9.0  Mid-range product  Regularly busy
# 88          1  ...    9.0  Mid-range product    Slowest days
# 89          1  ...    9.0  Mid-range product    Slowest days
# 90          0  ...    9.0  Mid-range product  Regularly busy
# 91          1  ...    9.0  Mid-range product  Regularly busy
# 92          0  ...    9.0  Mid-range product  Regularly busy
# 93          1  ...    9.0  Mid-range product  Regularly busy
# 94          0  ...    9.0  Mid-range product  Regularly busy
# 95          0  ...    9.0  Mid-range product  Regularly busy
# 96          0  ...    9.0  Mid-range product  Regularly busy
# 97          0  ...    9.0  Mid-range product    Slowest days
# 98          0  ...    9.0  Mid-range product    Busiest days
# 99          1  ...    9.0  Mid-range product    Slowest days
#
#     busiest_period_of_day max_order      loyalty_flag  avg_price  \
# 0          Average orders        10      New customer   6.367797
# 1          Average orders        10      New customer   6.367797
# 2             Most orders        10      New customer   6.367797
# 3          Average orders        10      New customer   6.367797
# 4             Most orders        10      New customer   6.367797
# 5          Average orders        10      New customer   6.367797
# 6             Most orders        10      New customer   6.367797
# 7             Most orders        10      New customer   6.367797
# 8             Most orders        10      New customer   6.367797
# 9          Average orders        10      New customer   6.367797
# 10            Most orders        22  Regular customer   3.980556
# 11            Most orders        22  Regular customer   3.980556
# 12            Most orders        22  Regular customer   3.980556
# 13            Most orders        22  Regular customer   3.980556
# 14            Most orders        22  Regular customer   3.980556
# 15            Most orders         9      New customer   8.372059
# 16            Most orders         9      New customer   8.372059
# 17         Average orders         9      New customer   8.372059
# 18            Most orders        33  Regular customer   7.012683
# 19         Average orders        20  Regular customer   8.137793
# 20            Most orders        20  Regular customer   8.137793
# 21            Most orders        11  Regular customer   7.444898
# 22            Most orders        11  Regular customer   7.444898
# 23            Most orders        27  Regular customer   6.356287
# 24            Most orders        27  Regular customer   6.356287
# 25            Most orders        27  Regular customer   6.356287
# 26            Most orders        27  Regular customer   6.356287
# 27         Average orders        27  Regular customer   6.356287
# 28            Most orders        27  Regular customer   6.356287
# 29            Most orders        27  Regular customer   6.356287
# 30            Most orders        27  Regular customer   6.356287
# 31            Most orders        27  Regular customer   6.356287
# 32            Most orders        27  Regular customer   6.356287
# 33            Most orders        27  Regular customer   6.356287
# 34            Most orders        27  Regular customer   6.356287
# 35         Average orders        27  Regular customer   6.356287
# 36            Most orders        27  Regular customer   6.356287
# 37            Most orders        24  Regular customer   7.656790
# 38            Most orders        24  Regular customer   7.656790
# 39            Most orders        24  Regular customer   7.656790
# 40            Most orders        24  Regular customer   7.656790
# 41            Most orders        24  Regular customer   7.656790
# 42            Most orders        24  Regular customer   7.656790
# 43            Most orders        24  Regular customer   7.656790
# 44            Most orders        24  Regular customer   7.656790
# 45            Most orders        24  Regular customer   7.656790
# 46            Most orders        24  Regular customer   7.656790
# 47            Most orders        24  Regular customer   7.656790
# 48            Most orders        24  Regular customer   7.656790
# 49            Most orders        24  Regular customer   7.656790
# 50            Most orders        24  Regular customer   7.656790
# 51            Most orders        24  Regular customer   7.656790
# 52            Most orders        24  Regular customer   7.656790
# 53            Most orders        24  Regular customer   7.656790
# 54            Most orders        24  Regular customer   7.656790
# 55            Most orders        24  Regular customer   7.656790
# 56            Most orders         7      New customer   8.165385
# 57         Average orders         7      New customer   8.165385
# 58            Most orders        19  Regular customer   6.441221
# 59            Most orders        19  Regular customer   6.441221
# 60            Most orders        19  Regular customer   6.441221
# 61            Most orders        19  Regular customer   6.441221
# 62            Most orders        19  Regular customer   6.441221
# 63            Most orders        19  Regular customer   6.441221
# 64            Most orders        19  Regular customer   6.441221
# 65            Most orders        19  Regular customer   6.441221
# 66            Most orders        19  Regular customer   6.441221
# 67            Most orders        14  Regular customer   8.028000
# 68            Most orders        14  Regular customer   8.028000
# 69            Most orders        14  Regular customer   8.028000
# 70            Most orders        14  Regular customer   8.028000
# 71            Most orders        14  Regular customer   8.028000
# 72            Most orders        14  Regular customer   8.028000
# 73         Average orders        14  Regular customer   8.028000
# 74         Average orders         6      New customer   5.850725
# 75            Most orders         3      New customer   9.385714
# 76         Average orders         3      New customer   9.385714
# 77            Most orders         6      New customer   7.715000
# 78            Most orders        58    Loyal customer   7.149730
# 79            Most orders        58    Loyal customer   7.149730
# 80            Most orders        58    Loyal customer   7.149730
# 81            Most orders        58    Loyal customer   7.149730
# 82            Most orders        58    Loyal customer   7.149730
# 83         Average orders        58    Loyal customer   7.149730
# 84            Most orders        58    Loyal customer   7.149730
# 85            Most orders        58    Loyal customer   7.149730
# 86            Most orders        58    Loyal customer   7.149730
# 87            Most orders        58    Loyal customer   7.149730
# 88            Most orders        58    Loyal customer   7.149730
# 89            Most orders        58    Loyal customer   7.149730
# 90            Most orders        70    Loyal customer   6.862397
# 91            Most orders        70    Loyal customer   6.862397
# 92         Average orders        51    Loyal customer   7.285597
# 93            Most orders        51    Loyal customer   7.285597
# 94            Most orders         8      New customer   7.705128
# 95            Most orders         3      New customer  10.006250
# 96         Average orders         3      New customer   8.496552
# 97            Most orders         8      New customer   7.396610
# 98         Average orders        22  Regular customer   7.387805
# 99         Average orders        22  Regular customer   7.387805
#
#     spending_flag median_days_since_prior_order   order_frequency_flag
# 0     Low spender                          20.0       Regular customer
# 1     Low spender                          20.0       Regular customer
# 2     Low spender                          20.0       Regular customer
# 3     Low spender                          20.0       Regular customer
# 4     Low spender                          20.0       Regular customer
# 5     Low spender                          20.0       Regular customer
# 6     Low spender                          20.0       Regular customer
# 7     Low spender                          20.0       Regular customer
# 8     Low spender                          20.0       Regular customer
# 9     Low spender                          20.0       Regular customer
# 10    Low spender                           8.0      Frequent customer
# 11    Low spender                           8.0      Frequent customer
# 12    Low spender                           8.0      Frequent customer
# 13    Low spender                           8.0      Frequent customer
# 14    Low spender                           8.0      Frequent customer
# 15    Low spender                           6.0      Frequent customer
# 16    Low spender                           6.0      Frequent customer
# 17    Low spender                           6.0      Frequent customer
# 18    Low spender                           7.0      Frequent customer
# 19    Low spender                           6.0      Frequent customer
# 20    Low spender                           6.0      Frequent customer
# 21    Low spender                          10.0      Frequent customer
# 22    Low spender                          10.0      Frequent customer
# 23    Low spender                           8.0      Frequent customer
# 24    Low spender                           8.0      Frequent customer
# 25    Low spender                           8.0      Frequent customer
# 26    Low spender                           8.0      Frequent customer
# 27    Low spender                           8.0      Frequent customer
# 28    Low spender                           8.0      Frequent customer
# 29    Low spender                           8.0      Frequent customer
# 30    Low spender                           8.0      Frequent customer
# 31    Low spender                           8.0      Frequent customer
# 32    Low spender                           8.0      Frequent customer
# 33    Low spender                           8.0      Frequent customer
# 34    Low spender                           8.0      Frequent customer
# 35    Low spender                           8.0      Frequent customer
# 36    Low spender                           8.0      Frequent customer
# 37    Low spender                           7.0      Frequent customer
# 38    Low spender                           7.0      Frequent customer
# 39    Low spender                           7.0      Frequent customer
# 40    Low spender                           7.0      Frequent customer
# 41    Low spender                           7.0      Frequent customer
# 42    Low spender                           7.0      Frequent customer
# 43    Low spender                           7.0      Frequent customer
# 44    Low spender                           7.0      Frequent customer
# 45    Low spender                           7.0      Frequent customer
# 46    Low spender                           7.0      Frequent customer
# 47    Low spender                           7.0      Frequent customer
# 48    Low spender                           7.0      Frequent customer
# 49    Low spender                           7.0      Frequent customer
# 50    Low spender                           7.0      Frequent customer
# 51    Low spender                           7.0      Frequent customer
# 52    Low spender                           7.0      Frequent customer
# 53    Low spender                           7.0      Frequent customer
# 54    Low spender                           7.0      Frequent customer
# 55    Low spender                           7.0      Frequent customer
# 56    Low spender                          30.0  Non-frequent customer
# 57    Low spender                          30.0  Non-frequent customer
# 58    Low spender                          11.0       Regular customer
# 59    Low spender                          11.0       Regular customer
# 60    Low spender                          11.0       Regular customer
# 61    Low spender                          11.0       Regular customer
# 62    Low spender                          11.0       Regular customer
# 63    Low spender                          11.0       Regular customer
# 64    Low spender                          11.0       Regular customer
# 65    Low spender                          11.0       Regular customer
# 66    Low spender                          11.0       Regular customer
# 67    Low spender                          24.5  Non-frequent customer
# 68    Low spender                          24.5  Non-frequent customer
# 69    Low spender                          24.5  Non-frequent customer
# 70    Low spender                          24.5  Non-frequent customer
# 71    Low spender                          24.5  Non-frequent customer
# 72    Low spender                          24.5  Non-frequent customer
# 73    Low spender                          24.5  Non-frequent customer
# 74    Low spender                          20.0       Regular customer
# 75    Low spender                          15.0       Regular customer
# 76    Low spender                          15.0       Regular customer
# 77    Low spender                          25.0  Non-frequent customer
# 78    Low spender                           4.0      Frequent customer
# 79    Low spender                           4.0      Frequent customer
# 80    Low spender                           4.0      Frequent customer
# 81    Low spender                           4.0      Frequent customer
# 82    Low spender                           4.0      Frequent customer
# 83    Low spender                           4.0      Frequent customer
# 84    Low spender                           4.0      Frequent customer
# 85    Low spender                           4.0      Frequent customer
# 86    Low spender                           4.0      Frequent customer
# 87    Low spender                           4.0      Frequent customer
# 88    Low spender                           4.0      Frequent customer
# 89    Low spender                           4.0      Frequent customer
# 90    Low spender                           5.0      Frequent customer
# 91    Low spender                           5.0      Frequent customer
# 92    Low spender                           7.0      Frequent customer
# 93    Low spender                           7.0      Frequent customer
# 94    Low spender                          30.0  Non-frequent customer
# 95   High spender                           4.0      Frequent customer
# 96    Low spender                           3.0      Frequent customer
# 97    Low spender                           5.0      Frequent customer
# 98    Low spender                           6.0      Frequent customer
# 99    Low spender                           6.0      Frequent customer
#
# [100 rows x 23 columns]

# %%
# Create flag to assign "loyalty" label

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check frequency of "loyalty_flag" column

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Check output for first 60 rows of "user_id", "loyalty_flag" and "order_number" columns

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# ## Step 5 - Check basic statistics

# %%
# Check statistics of "loyalty_flag" column

ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# The prices of products purchased by loyal customers are lower on average than those purchased by regular or new customers.

# %% [markdown]
# ## Step 6 - Create a spending flag

# %%
# Group data

ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check output

ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     0.0         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
#
#     reordered  ... prices    price_range_loc     busiest_day  \
# 0           0  ...    9.0  Mid-range product  Regularly busy
# 1           1  ...    9.0  Mid-range product    Slowest days
# 2           1  ...    9.0  Mid-range product    Slowest days
# 3           1  ...    9.0  Mid-range product    Slowest days
# 4           1  ...    9.0  Mid-range product    Slowest days
# 5           1  ...    9.0  Mid-range product  Regularly busy
# 6           1  ...    9.0  Mid-range product    Busiest days
# 7           1  ...    9.0  Mid-range product    Busiest days
# 8           1  ...    9.0  Mid-range product    Busiest days
# 9           1  ...    9.0  Mid-range product    Slowest days
# 10          0  ...    9.0  Mid-range product    Busiest days
# 11          1  ...    9.0  Mid-range product  Regularly busy
# 12          1  ...    9.0  Mid-range product  Regularly busy
# 13          1  ...    9.0  Mid-range product    Busiest days
# 14          1  ...    9.0  Mid-range product    Busiest days
#
#     busiest_period_of_day max_order      loyalty_flag avg_price  \
# 0          Average orders        10      New customer  6.367797
# 1          Average orders        10      New customer  6.367797
# 2             Most orders        10      New customer  6.367797
# 3          Average orders        10      New customer  6.367797
# 4             Most orders        10      New customer  6.367797
# 5          Average orders        10      New customer  6.367797
# 6             Most orders        10      New customer  6.367797
# 7             Most orders        10      New customer  6.367797
# 8             Most orders        10      New customer  6.367797
# 9          Average orders        10      New customer  6.367797
# 10            Most orders        22  Regular customer  3.980556
# 11            Most orders        22  Regular customer  3.980556
# 12            Most orders        22  Regular customer  3.980556
# 13            Most orders        22  Regular customer  3.980556
# 14            Most orders        22  Regular customer  3.980556
#
#     spending_flag median_days_since_prior_order  order_frequency_flag
# 0     Low spender                          20.0      Regular customer
# 1     Low spender                          20.0      Regular customer
# 2     Low spender                          20.0      Regular customer
# 3     Low spender                          20.0      Regular customer
# 4     Low spender                          20.0      Regular customer
# 5     Low spender                          20.0      Regular customer
# 6     Low spender                          20.0      Regular customer
# 7     Low spender                          20.0      Regular customer
# 8     Low spender                          20.0      Regular customer
# 9     Low spender                          20.0      Regular customer
# 10    Low spender                           8.0     Frequent customer
# 11    Low spender                           8.0     Frequent customer
# 12    Low spender                           8.0     Frequent customer
# 13    Low spender                           8.0     Frequent customer
# 14    Low spender                           8.0     Frequent customer
#
# [15 rows x 23 columns]

# %%
# Create flag to assign "spending" label

ords_prods_merge.loc[ords_prods_merge['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Check frequency of "spending_flag" column

ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
# Check output for first 60 rows of "user_id", "spending_flag" and "order_number" columns

ords_prods_merge[['user_id', 'spending_flag', 'order_number']].head(60)
# Out:
#     user_id spending_flag  order_number
# 0         1   Low spender             1
# 1         1   Low spender             2
# 2         1   Low spender             3
# 3         1   Low spender             4
# 4         1   Low spender             5
# 5         1   Low spender             6
# 6         1   Low spender             7
# 7         1   Low spender             8
# 8         1   Low spender             9
# 9         1   Low spender            10
# 10       15   Low spender            15
# 11       15   Low spender            17
# 12       15   Low spender            18
# 13       15   Low spender            21
# 14       15   Low spender            22
# 15       19   Low spender             2
# 16       19   Low spender             5
# 17       19   Low spender             7
# 18       21   Low spender            10
# 19       31   Low spender            10
# 20       31   Low spender            17
# 21       43   Low spender             6
# 22       43   Low spender             9
# 23       52   Low spender             1
# 24       52   Low spender             2
# 25       52   Low spender             3
# 26       52   Low spender             5
# 27       52   Low spender             7
# 28       52   Low spender             9
# 29       52   Low spender            10
# 30       52   Low spender            11
# 31       52   Low spender            12
# 32       52   Low spender            15
# 33       52   Low spender            17
# 34       52   Low spender            18
# 35       52   Low spender            19
# 36       52   Low spender            21
# 37       67   Low spender             1
# 38       67   Low spender             2
# 39       67   Low spender             3
# 40       67   Low spender             4
# 41       67   Low spender             5
# 42       67   Low spender             6
# 43       67   Low spender             8
# 44       67   Low spender             9
# 45       67   Low spender            10
# 46       67   Low spender            11
# 47       67   Low spender            12
# 48       67   Low spender            13
# 49       67   Low spender            14
# 50       67   Low spender            16
# 51       67   Low spender            18
# 52       67   Low spender            19
# 53       67   Low spender            21
# 54       67   Low spender            22
# 55       67   Low spender            23
# 56       81   Low spender             3
# 57       81   Low spender             5
# 58       82   Low spender             1
# 59       82   Low spender             3

# %% [markdown]
# ## Step 7 - Create an order frequency flag

# %%
# Group data

ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Check output

ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     0.0         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
#
#     reordered  ... prices    price_range_loc     busiest_day  \
# 0           0  ...    9.0  Mid-range product  Regularly busy
# 1           1  ...    9.0  Mid-range product    Slowest days
# 2           1  ...    9.0  Mid-range product    Slowest days
# 3           1  ...    9.0  Mid-range product    Slowest days
# 4           1  ...    9.0  Mid-range product    Slowest days
# 5           1  ...    9.0  Mid-range product  Regularly busy
# 6           1  ...    9.0  Mid-range product    Busiest days
# 7           1  ...    9.0  Mid-range product    Busiest days
# 8           1  ...    9.0  Mid-range product    Busiest days
# 9           1  ...    9.0  Mid-range product    Slowest days
# 10          0  ...    9.0  Mid-range product    Busiest days
# 11          1  ...    9.0  Mid-range product  Regularly busy
# 12          1  ...    9.0  Mid-range product  Regularly busy
# 13          1  ...    9.0  Mid-range product    Busiest days
# 14          1  ...    9.0  Mid-range product    Busiest days
#
#     busiest_period_of_day max_order      loyalty_flag avg_price  \
# 0          Average orders        10      New customer  6.367797
# 1          Average orders        10      New customer  6.367797
# 2             Most orders        10      New customer  6.367797
# 3          Average orders        10      New customer  6.367797
# 4             Most orders        10      New customer  6.367797
# 5          Average orders        10      New customer  6.367797
# 6             Most orders        10      New customer  6.367797
# 7             Most orders        10      New customer  6.367797
# 8             Most orders        10      New customer  6.367797
# 9          Average orders        10      New customer  6.367797
# 10            Most orders        22  Regular customer  3.980556
# 11            Most orders        22  Regular customer  3.980556
# 12            Most orders        22  Regular customer  3.980556
# 13            Most orders        22  Regular customer  3.980556
# 14            Most orders        22  Regular customer  3.980556
#
#     spending_flag median_days_since_prior_order  order_frequency_flag
# 0     Low spender                          20.0      Regular customer
# 1     Low spender                          20.0      Regular customer
# 2     Low spender                          20.0      Regular customer
# 3     Low spender                          20.0      Regular customer
# 4     Low spender                          20.0      Regular customer
# 5     Low spender                          20.0      Regular customer
# 6     Low spender                          20.0      Regular customer
# 7     Low spender                          20.0      Regular customer
# 8     Low spender                          20.0      Regular customer
# 9     Low spender                          20.0      Regular customer
# 10    Low spender                           8.0     Frequent customer
# 11    Low spender                           8.0     Frequent customer
# 12    Low spender                           8.0     Frequent customer
# 13    Low spender                           8.0     Frequent customer
# 14    Low spender                           8.0     Frequent customer
#
# [15 rows x 23 columns]

# %%
# Create flag to assign "order_frequency" label

ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] <= 20) & (ords_prods_merge['median_days_since_prior_order'] > 10), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Check frequency of "order_frequency_flag" column

ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        22796659
# Regular customer          6921472
# Non-frequent customer     2686728
# Name: order_frequency_flag, dtype: int64

# %%
# Check output for first 60 rows of "user_id", "order_frequency_flag" and "order_number" columns

ords_prods_merge[['user_id', 'order_frequency_flag', 'order_number']].head(60)
# Out:
#     user_id   order_frequency_flag  order_number
# 0         1       Regular customer             1
# 1         1       Regular customer             2
# 2         1       Regular customer             3
# 3         1       Regular customer             4
# 4         1       Regular customer             5
# 5         1       Regular customer             6
# 6         1       Regular customer             7
# 7         1       Regular customer             8
# 8         1       Regular customer             9
# 9         1       Regular customer            10
# 10       15      Frequent customer            15
# 11       15      Frequent customer            17
# 12       15      Frequent customer            18
# 13       15      Frequent customer            21
# 14       15      Frequent customer            22
# 15       19      Frequent customer             2
# 16       19      Frequent customer             5
# 17       19      Frequent customer             7
# 18       21      Frequent customer            10
# 19       31      Frequent customer            10
# 20       31      Frequent customer            17
# 21       43      Frequent customer             6
# 22       43      Frequent customer             9
# 23       52      Frequent customer             1
# 24       52      Frequent customer             2
# 25       52      Frequent customer             3
# 26       52      Frequent customer             5
# 27       52      Frequent customer             7
# 28       52      Frequent customer             9
# 29       52      Frequent customer            10
# 30       52      Frequent customer            11
# 31       52      Frequent customer            12
# 32       52      Frequent customer            15
# 33       52      Frequent customer            17
# 34       52      Frequent customer            18
# 35       52      Frequent customer            19
# 36       52      Frequent customer            21
# 37       67      Frequent customer             1
# 38       67      Frequent customer             2
# 39       67      Frequent customer             3
# 40       67      Frequent customer             4
# 41       67      Frequent customer             5
# 42       67      Frequent customer             6
# 43       67      Frequent customer             8
# 44       67      Frequent customer             9
# 45       67      Frequent customer            10
# 46       67      Frequent customer            11
# 47       67      Frequent customer            12
# 48       67      Frequent customer            13
# 49       67      Frequent customer            14
# 50       67      Frequent customer            16
# 51       67      Frequent customer            18
# 52       67      Frequent customer            19
# 53       67      Frequent customer            21
# 54       67      Frequent customer            22
# 55       67      Frequent customer            23
# 56       81  Non-frequent customer             3
# 57       81  Non-frequent customer             5
# 58       82       Regular customer             1
# 59       82       Regular customer             3

# %% [markdown]
# ## Step 9 - Export data

# %%
# Export dataframe to pkl

ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
